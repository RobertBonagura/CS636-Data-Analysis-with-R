# %% [markdown]
# Robert Bonagura
#
# Final Project

# %% [markdown]
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %%
train = read.csv("data/train.csv")
head(train)

for (i in train){
    plot(x=i, train$SalePrice, xlab=names(train)[i])
}
# Out:
#   Id MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape LandContour
# 1 1  60         RL       65           8450   Pave   NA    Reg      Lvl
# 2 2  20         RL       80           9600   Pave   NA    Reg      Lvl
# 3 3  60         RL       68          11250   Pave   NA    IR1      Lvl
# 4 4  70         RL       60           9550   Pave   NA    IR1      Lvl
# 5 5  60         RL       84          14260   Pave   NA    IR1      Lvl
# 6 6  50         RL       85          14115   Pave   NA    IR1      Lvl
#   Utilities ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold YrSold
# 1 AllPub    ... 0        NA     NA    NA            0      2     2008
# 2 AllPub    ... 0        NA     NA    NA            0      5     2007
# 3 AllPub    ... 0        NA     NA    NA            0      9     2008
# 4 AllPub    ... 0        NA     NA    NA            0      2     2006
# 5 AllPub    ... 0        NA     NA    NA            0     12     2008
# ...

# %%
train
# Out:
#      Id   MSSubClass MSZoning LotFrontage LotArea Street Alley LotShape
# 1     1    60        RL        65          8450   Pave   NA    Reg
# 2     2    20        RL        80          9600   Pave   NA    Reg
# 3     3    60        RL        68         11250   Pave   NA    IR1
# 4     4    70        RL        60          9550   Pave   NA    IR1
# 5     5    60        RL        84         14260   Pave   NA    IR1
# 6     6    50        RL        85         14115   Pave   NA    IR1
# 7     7    20        RL        75         10084   Pave   NA    Reg
# 8     8    60        RL        NA         10382   Pave   NA    IR1
# 9     9    50        RM        51          6120   Pave   NA    Reg
# 10   10   190        RL        50          7420   Pave   NA    Reg
# 11   11    20        RL        70         11200   Pave   NA    Reg
# 12   12    60        RL        85         11924   Pave   NA    IR1
# 13   13    20        RL        NA         12968   Pave   NA    IR2
# ...

# %%
model <- lm(SalePrice ~ LotArea + OverallQual + OverallCond + YearBuilt, data = train)
summary(model)
# Out:
# Call:
# lm(formula = SalePrice ~ LotArea + OverallQual + OverallCond +
#     YearBuilt, data = train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -268634  -26234   -3667   20004  393023
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -7.984e+05  1.032e+05  -7.733 1.94e-14 ***
# LotArea      1.500e+00  1.210e-01  12.397  < 2e-16 ***
# OverallQual  4.003e+04  1.079e+03  37.107  < 2e-16 ***
# OverallCond  2.736e+03  1.178e+03   2.323   0.0203 *
# YearBuilt    3.572e+02  5.279e+01   6.767 1.90e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 45770 on 1455 degrees of freedom
# Multiple R-squared:  0.6689,	Adjusted R-squared:  0.668
# F-statistic:   735 on 4 and 1455 DF,  p-value: < 2.2e-16

# %%
summary(model)$coefficient

confint(model)

sigma(model)/mean(train$SalePrice)
# Out:
#             Estimate      Std. Error   t value   Pr(>|t|)
# (Intercept) -7.984136e+05 1.032419e+05 -7.733428  1.942605e-14
# LotArea      1.499481e+00 1.209568e-01 12.396829  1.269000e-33
# OverallQual  4.002845e+04 1.078727e+03 37.107124 1.170950e-212
# OverallCond  2.736366e+03 1.177978e+03  2.322934  2.031999e-02
# YearBuilt    3.572131e+02 5.278759e+01  6.766990  1.900296e-11
#             2.5 %         97.5 %
# (Intercept) -1.000932e+06 -5.958948e+05
# LotArea      1.262213e+00  1.736749e+00
# OverallQual  3.791243e+04  4.214448e+04
# OverallCond  4.256489e+02  5.047083e+03
# YearBuilt    2.536652e+02  4.607610e+02
# [1] 0.2529998

# %%
fit = model
# Out:
# Error in qqPlot(fit, main = "QQ Plot"): could not find function "qqPlot"
# Traceback:

# %%
# Out:
# Error in .helpForCall(topicExpr, parent.frame()): no methods for ‘outlierTest’ and no documentation for it as a function
# Traceback:
#
# 1. `?`(outlierTest())
# 2. .helpForCall(topicExpr, parent.frame())
# 3. stop(gettextf("no methods for %s and no documentation for it as a function",
#  .     sQuote(f)), domain = NA)

# %%
https://www.sheffield.ac.uk/polopoly_fs/1.536483!/file/MASH_multiple_regression_R.pdf
